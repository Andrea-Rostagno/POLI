# %% [markdown]
# # Python Lab 00a: Introduzione a Pandas
# ## Francesco Della Santa, Matematica per l'Intelligenza Artificiale, Politecnico di Torino
#
# In questo notebook vedremo in azione i comandi basilari del modulo _pandas_, elencati nelle slide e durante la lezione.
#
# Per maggiori dettagli, si invita a consultare sempre la documentazione ufficiale al seguente link: https://pandas.pydata.org/docs/

# %%
import pandas as pd
import numpy as np
import matplotlib

# %% [markdown]
# ## Inizializzazione di Serie.
#
# ### Tramite array di dati

# %%
x = np.random.rand(10)
x
# Out:
# array([0.12726045, 0.61710283, 0.134776  , 0.34723674, 0.84699876,
#        0.51312743, 0.72211024, 0.30662708, 0.18294154, 0.98144295])

# %%
s1 = pd.Series(x, index=[f'index{i}' for i in range(1,11)], name='my_series1')
s2 = pd.Series(x, name='my_series2')

# %%
s1
# Out:
# index1     0.127260
# index2     0.617103
# index3     0.134776
# index4     0.347237
# index5     0.846999
# index6     0.513127
# index7     0.722110
# index8     0.306627
# index9     0.182942
# index10    0.981443
# Name: my_series1, dtype: float64

# %%
s2
# Out:
# 0    0.127260
# 1    0.617103
# 2    0.134776
# 3    0.347237
# 4    0.846999
# 5    0.513127
# 6    0.722110
# 7    0.306627
# 8    0.182942
# 9    0.981443
# Name: my_series2, dtype: float64

# %% [markdown]
# ### Tramite dizionario

# %%
d = {'Age':30, 'Height':185, 'Weight':90}
d
# Out:
# {'Age': 30, 'Height': 185, 'Weight': 90}

# %%
s1d = pd.Series(d)

# %%
s1d
# Out:
# Age        30
# Height    185
# Weight     90
# dtype: int64

# %% [markdown]
# ## Inizializzazione DataFrame
#
# ### Tramite dizionario

# %%
D = {'Float_random':np.random.rand(10), 'Integer_random':np.random.permutation(10)}
D
# Out:
# {'Float_random': array([0.18691285, 0.08797432, 0.02192905, 0.24864068, 0.67393773,
#         0.82069113, 0.88697885, 0.01709724, 0.47406713, 0.84754218]),
#  'Integer_random': array([0, 8, 3, 5, 6, 2, 4, 1, 9, 7])}

# %%
df1d = pd.DataFrame(D)
df1d
# Out:
#    Float_random  Integer_random
# 0      0.186913               0
# 1      0.087974               8
# 2      0.021929               3
# 3      0.248641               5
# 4      0.673938               6
# 5      0.820691               2
# 6      0.886979               4
# 7      0.017097               1
# 8      0.474067               9
# 9      0.847542               7

# %%
df1d.dtypes
# Out:
# Float_random      float64
# Integer_random      int32
# dtype: object

# %% [markdown]
# ### Tramite array di dati

# %%
X = np.random.rand(10,5)
X
# Out:
# array([[0.80823883, 0.04614801, 0.84652534, 0.07829117, 0.98407732],
#        [0.9411863 , 0.26113449, 0.81576555, 0.42017574, 0.61879889],
#        [0.28690229, 0.98733214, 0.08985215, 0.32415323, 0.86197333],
#        [0.30628247, 0.06327047, 0.18731655, 0.90374427, 0.83902616],
#        [0.12885026, 0.91804079, 0.9229341 , 0.7815553 , 0.66311568],
#        [0.46786366, 0.68877543, 0.86673193, 0.86769411, 0.77667754],
#        [0.66906181, 0.72684606, 0.84577839, 0.55485031, 0.2990085 ],
#        [0.4982112 , 0.25735381, 0.00773476, 0.95460385, 0.16883447],
#        [0.07592147, 0.02675595, 0.93071971, 0.69934299, 0.8859288 ],
#        [0.46970724, 0.88229128, 0.11045892, 0.68347169, 0.96826421]])

# %%
df1 = pd.DataFrame(X, index=range(1, X.shape[0] + 1), columns=[f'column_{i}' for i in range(1, X.shape[1] + 1)])
df1
# Out:
#     column_1  column_2  column_3  column_4  column_5
# 1   0.808239  0.046148  0.846525  0.078291  0.984077
# 2   0.941186  0.261134  0.815766  0.420176  0.618799
# 3   0.286902  0.987332  0.089852  0.324153  0.861973
# 4   0.306282  0.063270  0.187317  0.903744  0.839026
# 5   0.128850  0.918041  0.922934  0.781555  0.663116
# 6   0.467864  0.688775  0.866732  0.867694  0.776678
# 7   0.669062  0.726846  0.845778  0.554850  0.299008
# 8   0.498211  0.257354  0.007735  0.954604  0.168834
# 9   0.075921  0.026756  0.930720  0.699343  0.885929
# 10  0.469707  0.882291  0.110459  0.683472  0.968264

# %% [markdown]
# ## Estrarre/Aggiungere colonne

# %%
df1['column_2']
# Out:
# 1     0.046148
# 2     0.261134
# 3     0.987332
# 4     0.063270
# 5     0.918041
# 6     0.688775
# 7     0.726846
# 8     0.257354
# 9     0.026756
# 10    0.882291
# Name: column_2, dtype: float64

# %%
df1['column_6'] = np.random.rand(10)
df1
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 1   0.808239  0.046148  0.846525  0.078291  0.984077  0.367344
# 2   0.941186  0.261134  0.815766  0.420176  0.618799  0.542623
# 3   0.286902  0.987332  0.089852  0.324153  0.861973  0.816939
# 4   0.306282  0.063270  0.187317  0.903744  0.839026  0.276462
# 5   0.128850  0.918041  0.922934  0.781555  0.663116  0.752507
# 6   0.467864  0.688775  0.866732  0.867694  0.776678  0.167721
# 7   0.669062  0.726846  0.845778  0.554850  0.299008  0.092065
# 8   0.498211  0.257354  0.007735  0.954604  0.168834  0.651002
# 9   0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 10  0.469707  0.882291  0.110459  0.683472  0.968264  0.271890

# %% [markdown]
# ## Attributi di DataFrame
#
# Utilizzeremo il DataFrame df1 sopra definito.

# %%
df1.at[6, 'column_2']
# Out:
# 0.6887754252526739

# %%
df1.iat[5, 1]
# Out:
# 0.6887754252526739

# %%
df1.index
# Out:
# RangeIndex(start=1, stop=11, step=1)

# %%
df1.columns
# Out:
# Index(['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6'], dtype='object')

# %%
df1.axes
# Out:
# [RangeIndex(start=1, stop=11, step=1),
#  Index(['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6'], dtype='object')]

# %%
df1.loc[[1,7,10], :]
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 1   0.808239  0.046148  0.846525  0.078291  0.984077  0.367344
# 7   0.669062  0.726846  0.845778  0.554850  0.299008  0.092065
# 10  0.469707  0.882291  0.110459  0.683472  0.968264  0.271890

# %%
df1.loc[[1,7,10], ['column_1', 'column_3']]
# Out:
#     column_1  column_3
# 1   0.808239  0.846525
# 7   0.669062  0.845778
# 10  0.469707  0.110459

# %%
df1.iloc[[0,6,9],[0,2]]
# Out:
#     column_1  column_3
# 1   0.808239  0.846525
# 7   0.669062  0.845778
# 10  0.469707  0.110459

# %%
df1.loc[(df1.index > 3) & (df1.index <= 7), df1.columns != 'column_3']
# Out:
#    column_1  column_2  column_4  column_5  column_6
# 4  0.306282  0.063270  0.903744  0.839026  0.276462
# 5  0.128850  0.918041  0.781555  0.663116  0.752507
# 6  0.467864  0.688775  0.867694  0.776678  0.167721
# 7  0.669062  0.726846  0.554850  0.299008  0.092065

# %%
df1.shape
# Out:
# (10, 6)

# %%
df1.ndim
# Out:
# 2

# %%
df1.size
# Out:
# 60

# %%
df1.values
# Out:
# array([[0.80823883, 0.04614801, 0.84652534, 0.07829117, 0.98407732,
#         0.36734438],
#        [0.9411863 , 0.26113449, 0.81576555, 0.42017574, 0.61879889,
#         0.54262321],
#        [0.28690229, 0.98733214, 0.08985215, 0.32415323, 0.86197333,
#         0.81693906],
#        [0.30628247, 0.06327047, 0.18731655, 0.90374427, 0.83902616,
#         0.27646209],
#        [0.12885026, 0.91804079, 0.9229341 , 0.7815553 , 0.66311568,
#         0.75250684],
#        [0.46786366, 0.68877543, 0.86673193, 0.86769411, 0.77667754,
#         0.16772054],
#        [0.66906181, 0.72684606, 0.84577839, 0.55485031, 0.2990085 ,
#         0.0920653 ],
#        [0.4982112 , 0.25735381, 0.00773476, 0.95460385, 0.16883447,
#         0.65100194],
#        [0.07592147, 0.02675595, 0.93071971, 0.69934299, 0.8859288 ,
#         0.73645607],
#        [0.46970724, 0.88229128, 0.11045892, 0.68347169, 0.96826421,
#         0.27188971]])

# %% [markdown]
# ## Metodi di DataFrame
#
# Utilizzeremo il DataFrame df1 sopra definito.

# %% [markdown]
# ### Metodi di Esplorazione

# %%
df1.head(3)
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.808239  0.046148  0.846525  0.078291  0.984077  0.367344
# 2  0.941186  0.261134  0.815766  0.420176  0.618799  0.542623
# 3  0.286902  0.987332  0.089852  0.324153  0.861973  0.816939

# %%
df1.tail(2)
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 9   0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 10  0.469707  0.882291  0.110459  0.683472  0.968264  0.271890

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 1 to 10
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   column_1  10 non-null     float64
#  1   column_2  10 non-null     float64
#  2   column_3  10 non-null     float64
#  3   column_4  10 non-null     float64
#  4   column_5  10 non-null     float64
#  5   column_6  10 non-null     float64
# dtypes: float64(6)
# memory usage: 612.0 bytes

# %%
df1.nunique()
# Out:
# column_1    10
# column_2    10
# column_3    10
# column_4    10
# column_5    10
# column_6    10
# dtype: int64

# %%
df1.nunique(axis=1)
# Out:
# 1     6
# 2     6
# 3     6
# 4     6
# 5     6
# 6     6
# 7     6
# 8     6
# 9     6
# 10    6
# dtype: int64

# %%
df1.isna()
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 1      False     False     False     False     False     False
# 2      False     False     False     False     False     False
# 3      False     False     False     False     False     False
# 4      False     False     False     False     False     False
# 5      False     False     False     False     False     False
# 6      False     False     False     False     False     False
# 7      False     False     False     False     False     False
# 8      False     False     False     False     False     False
# 9      False     False     False     False     False     False
# 10     False     False     False     False     False     False

# %%
df1.count()
# Out:
# column_1    10
# column_2    10
# column_3    10
# column_4    10
# column_5    10
# column_6    10
# dtype: int64

# %%
df1.value_counts()
# Out:
# column_1  column_2  column_3  column_4  column_5  column_6
# 0.075921  0.026756  0.930720  0.699343  0.885929  0.736456    1
# 0.128850  0.918041  0.922934  0.781555  0.663116  0.752507    1
# 0.286902  0.987332  0.089852  0.324153  0.861973  0.816939    1
# 0.306282  0.063270  0.187317  0.903744  0.839026  0.276462    1
# 0.467864  0.688775  0.866732  0.867694  0.776678  0.167721    1
# 0.469707  0.882291  0.110459  0.683472  0.968264  0.271890    1
# 0.498211  0.257354  0.007735  0.954604  0.168834  0.651002    1
# 0.669062  0.726846  0.845778  0.554850  0.299008  0.092065    1
# 0.808239  0.046148  0.846525  0.078291  0.984077  0.367344    1
# 0.941186  0.261134  0.815766  0.420176  0.618799  0.542623    1
# Name: count, dtype: int64

# %%
df1.value_counts(normalize=True)
# Out:
# column_1  column_2  column_3  column_4  column_5  column_6
# 0.075921  0.026756  0.930720  0.699343  0.885929  0.736456    0.1
# 0.128850  0.918041  0.922934  0.781555  0.663116  0.752507    0.1
# 0.286902  0.987332  0.089852  0.324153  0.861973  0.816939    0.1
# 0.306282  0.063270  0.187317  0.903744  0.839026  0.276462    0.1
# 0.467864  0.688775  0.866732  0.867694  0.776678  0.167721    0.1
# 0.469707  0.882291  0.110459  0.683472  0.968264  0.271890    0.1
# 0.498211  0.257354  0.007735  0.954604  0.168834  0.651002    0.1
# 0.669062  0.726846  0.845778  0.554850  0.299008  0.092065    0.1
# 0.808239  0.046148  0.846525  0.078291  0.984077  0.367344    0.1
# 0.941186  0.261134  0.815766  0.420176  0.618799  0.542623    0.1
# Name: proportion, dtype: float64

# %% [markdown]
# ### Analisi Statistica di Base e Operazioni su Valori

# %%
df1.describe()
# Out:
#         column_1   column_2   column_3   column_4   column_5   column_6
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.465223   0.485795   0.562382   0.626788   0.706570   0.467501
# std     0.280600   0.391590   0.402683   0.281846   0.276713   0.264701
# min     0.075921   0.026756   0.007735   0.078291   0.168834   0.092065
# 25%     0.291747   0.111791   0.129673   0.453844   0.629878   0.273033
# 50%     0.468785   0.474955   0.830772   0.691407   0.807852   0.454984
# 75%     0.626349   0.843430   0.861680   0.846159   0.879940   0.715093
# max     0.941186   0.987332   0.930720   0.954604   0.984077   0.816939

# %%
df1.describe(percentiles=[0.13, 0.87, 0.99])
# Out:
#         column_1   column_2   column_3   column_4   column_5   column_6
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.465223   0.485795   0.562382   0.626788   0.706570   0.467501
# std     0.280600   0.391590   0.402683   0.281846   0.276713   0.264701
# min     0.075921   0.026756   0.007735   0.078291   0.168834   0.092065
# 13%     0.155719   0.049059   0.093355   0.340477   0.353373   0.185429
# 50%     0.468785   0.474955   0.830772   0.691407   0.807852   0.454984
# 87%     0.784579   0.911963   0.913380   0.897616   0.954267   0.749778
# 99%     0.929221   0.981096   0.930019   0.950026   0.982654   0.811140
# max     0.941186   0.987332   0.930720   0.954604   0.984077   0.816939

# %%
df1.mean()
# Out:
# column_1    0.465223
# column_2    0.485795
# column_3    0.562382
# column_4    0.626788
# column_5    0.706570
# column_6    0.467501
# dtype: float64

# %%
df1.mean(axis=1)
# Out:
# 1     0.521771
# 2     0.599947
# 3     0.561192
# 4     0.429350
# 5     0.694500
# 6     0.639244
# 7     0.531268
# 8     0.422957
# 9     0.559187
# 10    0.564347
# dtype: float64

# %%
df1.corr()
# Out:
#           column_1  column_2  column_3  column_4  column_5  column_6
# column_1  1.000000 -0.205063  0.133258 -0.505499 -0.214672 -0.453665
# column_2 -0.205063  1.000000 -0.138102  0.031710 -0.039825  0.012902
# column_3  0.133258 -0.138102  1.000000 -0.235994  0.069522 -0.116832
# column_4 -0.505499  0.031710 -0.235994  1.000000 -0.360972 -0.077099
# column_5 -0.214672 -0.039825  0.069522 -0.360972  1.000000  0.019110
# column_6 -0.453665  0.012902 -0.116832 -0.077099  0.019110  1.000000

# %%
df1.cov()
# Out:
#           column_1  column_2  column_3  column_4  column_5  column_6
# column_1  0.078737 -0.022532  0.015057 -0.039978 -0.016668 -0.033696
# column_2 -0.022532  0.153343 -0.021777  0.003500 -0.004315  0.001337
# column_3  0.015057 -0.021777  0.162153 -0.026784  0.007747 -0.012453
# column_4 -0.039978  0.003500 -0.026784  0.079437 -0.028152 -0.005752
# column_5 -0.016668 -0.004315  0.007747 -0.028152  0.076570  0.001400
# column_6 -0.033696  0.001337 -0.012453 -0.005752  0.001400  0.070067

# %%
df1.sample(3, random_state=10)
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 9  0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 3  0.286902  0.987332  0.089852  0.324153  0.861973  0.816939
# 6  0.467864  0.688775  0.866732  0.867694  0.776678  0.167721

# %% [markdown]
# ### Metodi di Trasformazione/Alterazione

# %%
df1_copy = df1.copy()
df1_fakecopy = df1

# %%
df1_fakecopy.at[1, 'column_1'] = 10

# %%
df1_copy.at[1, 'column_1'] = np.nan

# %%
df1_copy
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 1        NaN  0.046148  0.846525  0.078291  0.984077  0.367344
# 2   0.941186  0.261134  0.815766  0.420176  0.618799  0.542623
# 3   0.286902  0.987332  0.089852  0.324153  0.861973  0.816939
# 4   0.306282  0.063270  0.187317  0.903744  0.839026  0.276462
# 5   0.128850  0.918041  0.922934  0.781555  0.663116  0.752507
# 6   0.467864  0.688775  0.866732  0.867694  0.776678  0.167721
# 7   0.669062  0.726846  0.845778  0.554850  0.299008  0.092065
# 8   0.498211  0.257354  0.007735  0.954604  0.168834  0.651002
# 9   0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 10  0.469707  0.882291  0.110459  0.683472  0.968264  0.271890

# %%
df1
# Out:
#      column_1  column_2  column_3  column_4  column_5  column_6
# 1   10.000000  0.046148  0.846525  0.078291  0.984077  0.367344
# 2    0.941186  0.261134  0.815766  0.420176  0.618799  0.542623
# 3    0.286902  0.987332  0.089852  0.324153  0.861973  0.816939
# 4    0.306282  0.063270  0.187317  0.903744  0.839026  0.276462
# 5    0.128850  0.918041  0.922934  0.781555  0.663116  0.752507
# 6    0.467864  0.688775  0.866732  0.867694  0.776678  0.167721
# 7    0.669062  0.726846  0.845778  0.554850  0.299008  0.092065
# 8    0.498211  0.257354  0.007735  0.954604  0.168834  0.651002
# 9    0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 10   0.469707  0.882291  0.110459  0.683472  0.968264  0.271890

# %% [markdown]
# **NOTA BENE:** (Notare che la modifica fatta a df1_fakecopy ha modificato anche df1!)

# %%
pd.concat([df1,df1_copy], axis=0)
# Out:
#      column_1  column_2  column_3  column_4  column_5  column_6
# 1   10.000000  0.046148  0.846525  0.078291  0.984077  0.367344
# 2    0.941186  0.261134  0.815766  0.420176  0.618799  0.542623
# 3    0.286902  0.987332  0.089852  0.324153  0.861973  0.816939
# 4    0.306282  0.063270  0.187317  0.903744  0.839026  0.276462
# 5    0.128850  0.918041  0.922934  0.781555  0.663116  0.752507
# 6    0.467864  0.688775  0.866732  0.867694  0.776678  0.167721
# 7    0.669062  0.726846  0.845778  0.554850  0.299008  0.092065
# 8    0.498211  0.257354  0.007735  0.954604  0.168834  0.651002
# 9    0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 10   0.469707  0.882291  0.110459  0.683472  0.968264  0.271890
# 1         NaN  0.046148  0.846525  0.078291  0.984077  0.367344
# 2    0.941186  0.261134  0.815766  0.420176  0.618799  0.542623
# 3    0.286902  0.987332  0.089852  0.324153  0.861973  0.816939
# 4    0.306282  0.063270  0.187317  0.903744  0.839026  0.276462
# 5    0.128850  0.918041  0.922934  0.781555  0.663116  0.752507
# 6    0.467864  0.688775  0.866732  0.867694  0.776678  0.167721
# 7    0.669062  0.726846  0.845778  0.554850  0.299008  0.092065
# 8    0.498211  0.257354  0.007735  0.954604  0.168834  0.651002
# 9    0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 10   0.469707  0.882291  0.110459  0.683472  0.968264  0.271890

# %%
df1.drop([1, 3], axis=0)
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 2   0.941186  0.261134  0.815766  0.420176  0.618799  0.542623
# 4   0.306282  0.063270  0.187317  0.903744  0.839026  0.276462
# 5   0.128850  0.918041  0.922934  0.781555  0.663116  0.752507
# 6   0.467864  0.688775  0.866732  0.867694  0.776678  0.167721
# 7   0.669062  0.726846  0.845778  0.554850  0.299008  0.092065
# 8   0.498211  0.257354  0.007735  0.954604  0.168834  0.651002
# 9   0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 10  0.469707  0.882291  0.110459  0.683472  0.968264  0.271890

# %%
df1_copy.dropna()
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 2   0.941186  0.261134  0.815766  0.420176  0.618799  0.542623
# 3   0.286902  0.987332  0.089852  0.324153  0.861973  0.816939
# 4   0.306282  0.063270  0.187317  0.903744  0.839026  0.276462
# 5   0.128850  0.918041  0.922934  0.781555  0.663116  0.752507
# 6   0.467864  0.688775  0.866732  0.867694  0.776678  0.167721
# 7   0.669062  0.726846  0.845778  0.554850  0.299008  0.092065
# 8   0.498211  0.257354  0.007735  0.954604  0.168834  0.651002
# 9   0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 10  0.469707  0.882291  0.110459  0.683472  0.968264  0.271890

# %%
df1_copy.fillna(1000)
# Out:
#        column_1  column_2  column_3  column_4  column_5  column_6
# 1   1000.000000  0.046148  0.846525  0.078291  0.984077  0.367344
# 2      0.941186  0.261134  0.815766  0.420176  0.618799  0.542623
# 3      0.286902  0.987332  0.089852  0.324153  0.861973  0.816939
# 4      0.306282  0.063270  0.187317  0.903744  0.839026  0.276462
# 5      0.128850  0.918041  0.922934  0.781555  0.663116  0.752507
# 6      0.467864  0.688775  0.866732  0.867694  0.776678  0.167721
# 7      0.669062  0.726846  0.845778  0.554850  0.299008  0.092065
# 8      0.498211  0.257354  0.007735  0.954604  0.168834  0.651002
# 9      0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 10     0.469707  0.882291  0.110459  0.683472  0.968264  0.271890

# %%
df1_copy.rename(index={1:'nuovo_index'}, columns={'column_1':'COLONNA_1'})
# Out:
#              COLONNA_1  column_2  column_3  column_4  column_5  column_6
# nuovo_index        NaN  0.046148  0.846525  0.078291  0.984077  0.367344
# 2             0.941186  0.261134  0.815766  0.420176  0.618799  0.542623
# 3             0.286902  0.987332  0.089852  0.324153  0.861973  0.816939
# 4             0.306282  0.063270  0.187317  0.903744  0.839026  0.276462
# 5             0.128850  0.918041  0.922934  0.781555  0.663116  0.752507
# 6             0.467864  0.688775  0.866732  0.867694  0.776678  0.167721
# 7             0.669062  0.726846  0.845778  0.554850  0.299008  0.092065
# 8             0.498211  0.257354  0.007735  0.954604  0.168834  0.651002
# 9             0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 10            0.469707  0.882291  0.110459  0.683472  0.968264  0.271890

# %%
df1_copy.reset_index()
# Out:
#    index  column_1  column_2  column_3  column_4  column_5  column_6
# 0      1       NaN  0.046148  0.846525  0.078291  0.984077  0.367344
# 1      2  0.941186  0.261134  0.815766  0.420176  0.618799  0.542623
# 2      3  0.286902  0.987332  0.089852  0.324153  0.861973  0.816939
# 3      4  0.306282  0.063270  0.187317  0.903744  0.839026  0.276462
# 4      5  0.128850  0.918041  0.922934  0.781555  0.663116  0.752507
# 5      6  0.467864  0.688775  0.866732  0.867694  0.776678  0.167721
# 6      7  0.669062  0.726846  0.845778  0.554850  0.299008  0.092065
# 7      8  0.498211  0.257354  0.007735  0.954604  0.168834  0.651002
# 8      9  0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 9     10  0.469707  0.882291  0.110459  0.683472  0.968264  0.271890

# %%
df1_copy.sort_values('column_1')
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 9   0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 5   0.128850  0.918041  0.922934  0.781555  0.663116  0.752507
# 3   0.286902  0.987332  0.089852  0.324153  0.861973  0.816939
# 4   0.306282  0.063270  0.187317  0.903744  0.839026  0.276462
# 6   0.467864  0.688775  0.866732  0.867694  0.776678  0.167721
# 10  0.469707  0.882291  0.110459  0.683472  0.968264  0.271890
# 8   0.498211  0.257354  0.007735  0.954604  0.168834  0.651002
# 7   0.669062  0.726846  0.845778  0.554850  0.299008  0.092065
# 2   0.941186  0.261134  0.815766  0.420176  0.618799  0.542623
# 1        NaN  0.046148  0.846525  0.078291  0.984077  0.367344

# %% [markdown]
# (Notare il NaN messo in fondo; per maggiori informazioni, guardare la documentazione ufficiale)

# %% [markdown]
# ### Metodi di Esportazione

# %%
df1.to_csv('df1.csv', columns=['column_1', 'column_5', 'column_2'], index_label='ID')

# %%
df1.to_pickle('df1.pkl')

# %% [markdown]
# ### Metodi di Visualizzazione

# %%
df1_plot = df1.sort_values('column_1')
df1_plot.plot('column_1', ['column_6', 'column_3'], figsize=(12,8))
# Out:
# <Axes: xlabel='column_1'>

# %%
df1.plot.scatter(x='column_2', y='column_5', c='column_3', colormap='autumn', figsize=(12,8))
# Out:
# <Axes: xlabel='column_2', ylabel='column_5'>

# %%
df1.boxplot(column=['column_3', 'column_2'], figsize=(12,8))
# Out:
# <Axes: >

# %%
df1.loc[:, df1.columns!='column_1'].plot.bar(figsize=(12,8))
# Out:
# <Axes: >

# %%
df1.loc[:, df1.columns!='column_1'].plot.density(figsize=(12,8))
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Caricamento DataFrame

# %%
pd.read_csv('df1.csv')
# Out:
#    ID   column_1  column_5  column_2
# 0   1  10.000000  0.984077  0.046148
# 1   2   0.941186  0.618799  0.261134
# 2   3   0.286902  0.861973  0.987332
# 3   4   0.306282  0.839026  0.063270
# 4   5   0.128850  0.663116  0.918041
# 5   6   0.467864  0.776678  0.688775
# 6   7   0.669062  0.299008  0.726846
# 7   8   0.498211  0.168834  0.257354
# 8   9   0.075921  0.885929  0.026756
# 9  10   0.469707  0.968264  0.882291

# %%
pd.read_csv('df1.csv', usecols=['ID', 'column_1', 'column_2'], index_col='ID')
# Out:
#      column_1  column_2
# ID
# 1   10.000000  0.046148
# 2    0.941186  0.261134
# 3    0.286902  0.987332
# 4    0.306282  0.063270
# 5    0.128850  0.918041
# 6    0.467864  0.688775
# 7    0.669062  0.726846
# 8    0.498211  0.257354
# 9    0.075921  0.026756
# 10   0.469707  0.882291

# %%
pd.read_pickle('df1.pkl')
# Out:
#      column_1  column_2  column_3  column_4  column_5  column_6
# 1   10.000000  0.046148  0.846525  0.078291  0.984077  0.367344
# 2    0.941186  0.261134  0.815766  0.420176  0.618799  0.542623
# 3    0.286902  0.987332  0.089852  0.324153  0.861973  0.816939
# 4    0.306282  0.063270  0.187317  0.903744  0.839026  0.276462
# 5    0.128850  0.918041  0.922934  0.781555  0.663116  0.752507
# 6    0.467864  0.688775  0.866732  0.867694  0.776678  0.167721
# 7    0.669062  0.726846  0.845778  0.554850  0.299008  0.092065
# 8    0.498211  0.257354  0.007735  0.954604  0.168834  0.651002
# 9    0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 10   0.469707  0.882291  0.110459  0.683472  0.968264  0.271890

# %% [markdown]
# ## "Affiancamento" di DataFrame

# %%
pd.concat([df1, df1.reset_index()], axis=1)
# Out:
#      column_1  column_2  column_3  column_4  column_5  column_6  index  \
# 1   10.000000  0.046148  0.846525  0.078291  0.984077  0.367344    2.0
# 2    0.941186  0.261134  0.815766  0.420176  0.618799  0.542623    3.0
# 3    0.286902  0.987332  0.089852  0.324153  0.861973  0.816939    4.0
# 4    0.306282  0.063270  0.187317  0.903744  0.839026  0.276462    5.0
# 5    0.128850  0.918041  0.922934  0.781555  0.663116  0.752507    6.0
# 6    0.467864  0.688775  0.866732  0.867694  0.776678  0.167721    7.0
# 7    0.669062  0.726846  0.845778  0.554850  0.299008  0.092065    8.0
# 8    0.498211  0.257354  0.007735  0.954604  0.168834  0.651002    9.0
# 9    0.075921  0.026756  0.930720  0.699343  0.885929  0.736456   10.0
# 10   0.469707  0.882291  0.110459  0.683472  0.968264  0.271890    NaN
# 0         NaN       NaN       NaN       NaN       NaN       NaN    1.0
#
#      column_1  column_2  column_3  column_4  column_5  column_6
# 1    0.941186  0.261134  0.815766  0.420176  0.618799  0.542623
# 2    0.286902  0.987332  0.089852  0.324153  0.861973  0.816939
# 3    0.306282  0.063270  0.187317  0.903744  0.839026  0.276462
# 4    0.128850  0.918041  0.922934  0.781555  0.663116  0.752507
# 5    0.467864  0.688775  0.866732  0.867694  0.776678  0.167721
# 6    0.669062  0.726846  0.845778  0.554850  0.299008  0.092065
# 7    0.498211  0.257354  0.007735  0.954604  0.168834  0.651002
# 8    0.075921  0.026756  0.930720  0.699343  0.885929  0.736456
# 9    0.469707  0.882291  0.110459  0.683472  0.968264  0.271890
# 10        NaN       NaN       NaN       NaN       NaN       NaN
# 0   10.000000  0.046148  0.846525  0.078291  0.984077  0.367344
