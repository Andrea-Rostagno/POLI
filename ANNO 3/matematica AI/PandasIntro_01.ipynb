# %% [markdown]
# # Python Lab 00a: Introduzione a Pandas
# ## Francesco Della Santa, Matematica per l'Intelligenza Artificiale, Politecnico di Torino
#
# In questo notebook vedremo in azione i comandi basilari del modulo _pandas_, elencati nelle slide e durante la lezione.
#
# Per maggiori dettagli, si invita a consultare sempre la documentazione ufficiale al seguente link: https://pandas.pydata.org/docs/

# %%
import pandas as pd
import numpy as np
import matplotlib

# %% [markdown]
# ## Inizializzazione di Serie.
#
# ### Tramite array di dati

# %%
x = np.random.rand(10)
x
# Out:
# array([0.19175089, 0.77832108, 0.82542791, 0.11569208, 0.15821805,
#        0.1181571 , 0.70961316, 0.96565508, 0.14890034, 0.45612525])

# %%
s1 = pd.Series(x, index=[f'index{i}' for i in range(1,11)], name='my_series1')
s2 = pd.Series(x, name='my_series2')

# %%
s1
# Out:
# index1     0.191751
# index2     0.778321
# index3     0.825428
# index4     0.115692
# index5     0.158218
# index6     0.118157
# index7     0.709613
# index8     0.965655
# index9     0.148900
# index10    0.456125
# Name: my_series1, dtype: float64

# %%
s2
# Out:
# 0    0.191751
# 1    0.778321
# 2    0.825428
# 3    0.115692
# 4    0.158218
# 5    0.118157
# 6    0.709613
# 7    0.965655
# 8    0.148900
# 9    0.456125
# Name: my_series2, dtype: float64

# %% [markdown]
# ### Tramite dizionario

# %%
d = {'Age':30, 'Height':185, 'Weight':90}
d
# Out:
# {'Age': 30, 'Height': 185, 'Weight': 90}

# %%
s1d = pd.Series(d)

# %%
s1d
# Out:
# Age        30
# Height    185
# Weight     90
# dtype: int64

# %% [markdown]
# ## Inizializzazione DataFrame
#
# ### Tramite dizionario

# %%
D = {'Float_random':np.random.rand(10), 'Integer_random':np.random.permutation(10)}
D
# Out:
# {'Float_random': array([0.5482784 , 0.39702273, 0.75646757, 0.14889303, 0.42661747,
#         0.13857958, 0.92601631, 0.49141405, 0.51819023, 0.73403279]),
#  'Integer_random': array([1, 2, 0, 9, 4, 5, 8, 3, 6, 7])}

# %%
df1d = pd.DataFrame(D)
df1d
# Out:
#    Float_random  Integer_random
# 0      0.548278               1
# 1      0.397023               2
# 2      0.756468               0
# 3      0.148893               9
# 4      0.426617               4
# 5      0.138580               5
# 6      0.926016               8
# 7      0.491414               3
# 8      0.518190               6
# 9      0.734033               7

# %%
df1d.dtypes
# Out:
# Float_random      float64
# Integer_random      int32
# dtype: object

# %% [markdown]
# ### Tramite array di dati

# %%
X = np.random.rand(10,5)
X
# Out:
# array([[0.14935663, 0.65385867, 0.58921115, 0.74611275, 0.80306291],
#        [0.9264334 , 0.42259261, 0.37738887, 0.19798058, 0.44102837],
#        [0.46111337, 0.51587246, 0.97272982, 0.12321157, 0.58894534],
#        [0.55608266, 0.04034026, 0.18943583, 0.56069355, 0.54608541],
#        [0.55865623, 0.40184308, 0.04283608, 0.07162541, 0.05089013],
#        [0.42018001, 0.14999862, 0.84981383, 0.43110819, 0.34720817],
#        [0.24518378, 0.67440092, 0.27281756, 0.96464513, 0.89533397],
#        [0.09166823, 0.40332305, 0.42857305, 0.24436617, 0.96170584],
#        [0.89422852, 0.19050453, 0.61264273, 0.86958612, 0.04674826],
#        [0.16306858, 0.7273785 , 0.05010949, 0.69893207, 0.42224264]])

# %%
df1 = pd.DataFrame(X, index=range(1, X.shape[0] + 1), columns=[f'column_{i}' for i in range(1, X.shape[1] + 1)])
df1
# Out:
#     column_1  column_2  column_3  column_4  column_5
# 1   0.149357  0.653859  0.589211  0.746113  0.803063
# 2   0.926433  0.422593  0.377389  0.197981  0.441028
# 3   0.461113  0.515872  0.972730  0.123212  0.588945
# 4   0.556083  0.040340  0.189436  0.560694  0.546085
# 5   0.558656  0.401843  0.042836  0.071625  0.050890
# 6   0.420180  0.149999  0.849814  0.431108  0.347208
# 7   0.245184  0.674401  0.272818  0.964645  0.895334
# 8   0.091668  0.403323  0.428573  0.244366  0.961706
# 9   0.894229  0.190505  0.612643  0.869586  0.046748
# 10  0.163069  0.727378  0.050109  0.698932  0.422243

# %% [markdown]
# ## Estrarre/Aggiungere colonne

# %%
df1['column_2']
# Out:
# 1     0.653859
# 2     0.422593
# 3     0.515872
# 4     0.040340
# 5     0.401843
# 6     0.149999
# 7     0.674401
# 8     0.403323
# 9     0.190505
# 10    0.727378
# Name: column_2, dtype: float64

# %%
df1['column_6'] = np.random.rand(10)
df1
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 1   0.149357  0.653859  0.589211  0.746113  0.803063  0.778985
# 2   0.926433  0.422593  0.377389  0.197981  0.441028  0.232899
# 3   0.461113  0.515872  0.972730  0.123212  0.588945  0.301938
# 4   0.556083  0.040340  0.189436  0.560694  0.546085  0.020020
# 5   0.558656  0.401843  0.042836  0.071625  0.050890  0.226957
# 6   0.420180  0.149999  0.849814  0.431108  0.347208  0.371126
# 7   0.245184  0.674401  0.272818  0.964645  0.895334  0.785849
# 8   0.091668  0.403323  0.428573  0.244366  0.961706  0.071670
# 9   0.894229  0.190505  0.612643  0.869586  0.046748  0.759584
# 10  0.163069  0.727378  0.050109  0.698932  0.422243  0.978948

# %% [markdown]
# ## Attributi di DataFrame
#
# Utilizzeremo il DataFrame df1 sopra definito.

# %%
df1.at[6, 'column_2']
# Out:
# 0.14999861912717138

# %%
df1.iat[5, 1]
# Out:
# 0.14999861912717138

# %%
df1.index
# Out:
# RangeIndex(start=1, stop=11, step=1)

# %%
df1.columns
# Out:
# Index(['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6'], dtype='object')

# %%
df1.axes
# Out:
# [RangeIndex(start=1, stop=11, step=1),
#  Index(['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6'], dtype='object')]

# %%
df1.loc[[1,7,10], :]
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 1   0.149357  0.653859  0.589211  0.746113  0.803063  0.778985
# 7   0.245184  0.674401  0.272818  0.964645  0.895334  0.785849
# 10  0.163069  0.727378  0.050109  0.698932  0.422243  0.978948

# %%
df1.loc[[1,7,10], ['column_1', 'column_3']]
# Out:
#     column_1  column_3
# 1   0.149357  0.589211
# 7   0.245184  0.272818
# 10  0.163069  0.050109

# %%
df1.iloc[[0,6,9],[0,2]]
# Out:
#     column_1  column_3
# 1   0.149357  0.589211
# 7   0.245184  0.272818
# 10  0.163069  0.050109

# %%
df1.loc[(df1.index > 3) & (df1.index <= 7), df1.columns != 'column_3']
# Out:
#    column_1  column_2  column_4  column_5  column_6
# 4  0.556083  0.040340  0.560694  0.546085  0.020020
# 5  0.558656  0.401843  0.071625  0.050890  0.226957
# 6  0.420180  0.149999  0.431108  0.347208  0.371126
# 7  0.245184  0.674401  0.964645  0.895334  0.785849

# %%
df1.shape
# Out:
# (10, 6)

# %%
df1.ndim
# Out:
# 2

# %%
df1.size
# Out:
# 60

# %%
df1.values
# Out:
# array([[0.14935663, 0.65385867, 0.58921115, 0.74611275, 0.80306291,
#         0.77898473],
#        [0.9264334 , 0.42259261, 0.37738887, 0.19798058, 0.44102837,
#         0.23289886],
#        [0.46111337, 0.51587246, 0.97272982, 0.12321157, 0.58894534,
#         0.30193822],
#        [0.55608266, 0.04034026, 0.18943583, 0.56069355, 0.54608541,
#         0.02002042],
#        [0.55865623, 0.40184308, 0.04283608, 0.07162541, 0.05089013,
#         0.22695683],
#        [0.42018001, 0.14999862, 0.84981383, 0.43110819, 0.34720817,
#         0.37112648],
#        [0.24518378, 0.67440092, 0.27281756, 0.96464513, 0.89533397,
#         0.78584915],
#        [0.09166823, 0.40332305, 0.42857305, 0.24436617, 0.96170584,
#         0.07166956],
#        [0.89422852, 0.19050453, 0.61264273, 0.86958612, 0.04674826,
#         0.7595835 ],
#        [0.16306858, 0.7273785 , 0.05010949, 0.69893207, 0.42224264,
#         0.97894782]])

# %% [markdown]
# ## Metodi di DataFrame
#
# Utilizzeremo il DataFrame df1 sopra definito.

# %% [markdown]
# ### Metodi di Esplorazione

# %%
df1.head(3)
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.149357  0.653859  0.589211  0.746113  0.803063  0.778985
# 2  0.926433  0.422593  0.377389  0.197981  0.441028  0.232899
# 3  0.461113  0.515872  0.972730  0.123212  0.588945  0.301938

# %%
df1.tail(2)
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 9   0.894229  0.190505  0.612643  0.869586  0.046748  0.759584
# 10  0.163069  0.727378  0.050109  0.698932  0.422243  0.978948

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 1 to 10
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   column_1  10 non-null     float64
#  1   column_2  10 non-null     float64
#  2   column_3  10 non-null     float64
#  3   column_4  10 non-null     float64
#  4   column_5  10 non-null     float64
#  5   column_6  10 non-null     float64
# dtypes: float64(6)
# memory usage: 612.0 bytes

# %%
df1.nunique()
# Out:
# column_1    10
# column_2    10
# column_3    10
# column_4    10
# column_5    10
# column_6    10
# dtype: int64

# %%
df1.nunique(axis=1)
# Out:
# 1     6
# 2     6
# 3     6
# 4     6
# 5     6
# 6     6
# 7     6
# 8     6
# 9     6
# 10    6
# dtype: int64

# %%
df1.isna()
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 1      False     False     False     False     False     False
# 2      False     False     False     False     False     False
# 3      False     False     False     False     False     False
# 4      False     False     False     False     False     False
# 5      False     False     False     False     False     False
# 6      False     False     False     False     False     False
# 7      False     False     False     False     False     False
# 8      False     False     False     False     False     False
# 9      False     False     False     False     False     False
# 10     False     False     False     False     False     False

# %%
df1.count()
# Out:
# column_1    10
# column_2    10
# column_3    10
# column_4    10
# column_5    10
# column_6    10
# dtype: int64

# %%
df1.value_counts()
# Out:
# column_1  column_2  column_3  column_4  column_5  column_6
# 0.091668  0.403323  0.428573  0.244366  0.961706  0.071670    1
# 0.149357  0.653859  0.589211  0.746113  0.803063  0.778985    1
# 0.163069  0.727378  0.050109  0.698932  0.422243  0.978948    1
# 0.245184  0.674401  0.272818  0.964645  0.895334  0.785849    1
# 0.420180  0.149999  0.849814  0.431108  0.347208  0.371126    1
# 0.461113  0.515872  0.972730  0.123212  0.588945  0.301938    1
# 0.556083  0.040340  0.189436  0.560694  0.546085  0.020020    1
# 0.558656  0.401843  0.042836  0.071625  0.050890  0.226957    1
# 0.894229  0.190505  0.612643  0.869586  0.046748  0.759584    1
# 0.926433  0.422593  0.377389  0.197981  0.441028  0.232899    1
# Name: count, dtype: int64

# %%
df1.value_counts(normalize=True)
# Out:
# column_1  column_2  column_3  column_4  column_5  column_6
# 0.091668  0.403323  0.428573  0.244366  0.961706  0.071670    0.1
# 0.149357  0.653859  0.589211  0.746113  0.803063  0.778985    0.1
# 0.163069  0.727378  0.050109  0.698932  0.422243  0.978948    0.1
# 0.245184  0.674401  0.272818  0.964645  0.895334  0.785849    0.1
# 0.420180  0.149999  0.849814  0.431108  0.347208  0.371126    0.1
# 0.461113  0.515872  0.972730  0.123212  0.588945  0.301938    0.1
# 0.556083  0.040340  0.189436  0.560694  0.546085  0.020020    0.1
# 0.558656  0.401843  0.042836  0.071625  0.050890  0.226957    0.1
# 0.894229  0.190505  0.612643  0.869586  0.046748  0.759584    0.1
# 0.926433  0.422593  0.377389  0.197981  0.441028  0.232899    0.1
# Name: proportion, dtype: float64

# %% [markdown]
# ### Analisi Statistica di Base e Operazioni su Valori

# %%
df1.describe()
# Out:
#         column_1   column_2   column_3   column_4   column_5   column_6
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.446597   0.418011   0.438556   0.490826   0.510325   0.452798
# std     0.296527   0.234134   0.317689   0.323567   0.318029   0.341503
# min     0.091668   0.040340   0.042836   0.071625   0.046748   0.020020
# 25%     0.183597   0.243339   0.210281   0.209577   0.365967   0.228442
# 50%     0.440647   0.412958   0.402981   0.495901   0.493557   0.336532
# 75%     0.558013   0.619362   0.606785   0.734318   0.749534   0.774134
# max     0.926433   0.727378   0.972730   0.964645   0.961706   0.978948

# %%
df1.describe(percentiles=[0.13, 0.87, 0.99])
# Out:
#         column_1   column_2   column_3   column_4   column_5   column_6
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.446597   0.418011   0.438556   0.490826   0.510325   0.452798
# std     0.296527   0.234134   0.317689   0.323567   0.318029   0.341503
# min     0.091668   0.040340   0.042836   0.071625   0.046748   0.020020
# 13%     0.151688   0.156885   0.073795   0.135922   0.101264   0.098068
# 50%     0.440647   0.412958   0.402981   0.495901   0.493557   0.336532
# 87%     0.837181   0.670909   0.809495   0.848596   0.879648   0.784682
# 99%     0.923535   0.722611   0.961667   0.956090   0.955732   0.961569
# max     0.926433   0.727378   0.972730   0.964645   0.961706   0.978948

# %%
df1.mean()
# Out:
# column_1    0.446597
# column_2    0.418011
# column_3    0.438556
# column_4    0.490826
# column_5    0.510325
# column_6    0.452798
# dtype: float64

# %%
df1.mean(axis=1)
# Out:
# 1     0.620098
# 2     0.433054
# 3     0.493968
# 4     0.318776
# 5     0.225468
# 6     0.428239
# 7     0.639705
# 8     0.366884
# 9     0.562216
# 10    0.506780
# dtype: float64

# %%
df1.corr()
# Out:
#           column_1  column_2  column_3  column_4  column_5  column_6
# column_1  1.000000 -0.541811  0.089791 -0.181700 -0.686520 -0.240134
# column_2 -0.541811  1.000000 -0.185736  0.179814  0.424317  0.603258
# column_3  0.089791 -0.185736  1.000000 -0.115708  0.089463 -0.058137
# column_4 -0.181700  0.179814 -0.115708  1.000000  0.160042  0.754025
# column_5 -0.686520  0.424317  0.089463  0.160042  1.000000 -0.032635
# column_6 -0.240134  0.603258 -0.058137  0.754025 -0.032635  1.000000

# %%
df1.cov()
# Out:
#           column_1  column_2  column_3  column_4  column_5  column_6
# column_1  0.087928 -0.037616  0.008459 -0.017433 -0.064742 -0.024317
# column_2 -0.037616  0.054819 -0.013815  0.013622  0.031595  0.048235
# column_3  0.008459 -0.013815  0.100926 -0.011894  0.009039 -0.006307
# column_4 -0.017433  0.013622 -0.011894  0.104696  0.016469  0.083319
# column_5 -0.064742  0.031595  0.009039  0.016469  0.101143 -0.003544
# column_6 -0.024317  0.048235 -0.006307  0.083319 -0.003544  0.116624

# %%
df1.sample(3, random_state=10)
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 9  0.894229  0.190505  0.612643  0.869586  0.046748  0.759584
# 3  0.461113  0.515872  0.972730  0.123212  0.588945  0.301938
# 6  0.420180  0.149999  0.849814  0.431108  0.347208  0.371126

# %% [markdown]
# ### Metodi di Trasformazione/Alterazione

# %%
df1_copy = df1.copy()
df1_fakecopy = df1

# %%
df1_fakecopy.at[1, 'column_1'] = 10

# %%
df1_copy.at[1, 'column_1'] = np.nan

# %%
df1_copy
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 1        NaN  0.653859  0.589211  0.746113  0.803063  0.778985
# 2   0.926433  0.422593  0.377389  0.197981  0.441028  0.232899
# 3   0.461113  0.515872  0.972730  0.123212  0.588945  0.301938
# 4   0.556083  0.040340  0.189436  0.560694  0.546085  0.020020
# 5   0.558656  0.401843  0.042836  0.071625  0.050890  0.226957
# 6   0.420180  0.149999  0.849814  0.431108  0.347208  0.371126
# 7   0.245184  0.674401  0.272818  0.964645  0.895334  0.785849
# 8   0.091668  0.403323  0.428573  0.244366  0.961706  0.071670
# 9   0.894229  0.190505  0.612643  0.869586  0.046748  0.759584
# 10  0.163069  0.727378  0.050109  0.698932  0.422243  0.978948

# %%
df1
# Out:
#      column_1  column_2  column_3  column_4  column_5  column_6
# 1   10.000000  0.653859  0.589211  0.746113  0.803063  0.778985
# 2    0.926433  0.422593  0.377389  0.197981  0.441028  0.232899
# 3    0.461113  0.515872  0.972730  0.123212  0.588945  0.301938
# 4    0.556083  0.040340  0.189436  0.560694  0.546085  0.020020
# 5    0.558656  0.401843  0.042836  0.071625  0.050890  0.226957
# 6    0.420180  0.149999  0.849814  0.431108  0.347208  0.371126
# 7    0.245184  0.674401  0.272818  0.964645  0.895334  0.785849
# 8    0.091668  0.403323  0.428573  0.244366  0.961706  0.071670
# 9    0.894229  0.190505  0.612643  0.869586  0.046748  0.759584
# 10   0.163069  0.727378  0.050109  0.698932  0.422243  0.978948

# %% [markdown]
# **NOTA BENE:** (Notare che la modifica fatta a df1_fakecopy ha modificato anche df1!)

# %%
pd.concat([df1,df1_copy], axis=0)
# Out:
#      column_1  column_2  column_3  column_4  column_5  column_6
# 1   10.000000  0.653859  0.589211  0.746113  0.803063  0.778985
# 2    0.926433  0.422593  0.377389  0.197981  0.441028  0.232899
# 3    0.461113  0.515872  0.972730  0.123212  0.588945  0.301938
# 4    0.556083  0.040340  0.189436  0.560694  0.546085  0.020020
# 5    0.558656  0.401843  0.042836  0.071625  0.050890  0.226957
# 6    0.420180  0.149999  0.849814  0.431108  0.347208  0.371126
# 7    0.245184  0.674401  0.272818  0.964645  0.895334  0.785849
# 8    0.091668  0.403323  0.428573  0.244366  0.961706  0.071670
# 9    0.894229  0.190505  0.612643  0.869586  0.046748  0.759584
# 10   0.163069  0.727378  0.050109  0.698932  0.422243  0.978948
# 1         NaN  0.653859  0.589211  0.746113  0.803063  0.778985
# 2    0.926433  0.422593  0.377389  0.197981  0.441028  0.232899
# 3    0.461113  0.515872  0.972730  0.123212  0.588945  0.301938
# 4    0.556083  0.040340  0.189436  0.560694  0.546085  0.020020
# ...

# %%
df1.drop([1, 3], axis=0)
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 2   0.926433  0.422593  0.377389  0.197981  0.441028  0.232899
# 4   0.556083  0.040340  0.189436  0.560694  0.546085  0.020020
# 5   0.558656  0.401843  0.042836  0.071625  0.050890  0.226957
# 6   0.420180  0.149999  0.849814  0.431108  0.347208  0.371126
# 7   0.245184  0.674401  0.272818  0.964645  0.895334  0.785849
# 8   0.091668  0.403323  0.428573  0.244366  0.961706  0.071670
# 9   0.894229  0.190505  0.612643  0.869586  0.046748  0.759584
# 10  0.163069  0.727378  0.050109  0.698932  0.422243  0.978948

# %%
df1_copy.dropna()
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 2   0.926433  0.422593  0.377389  0.197981  0.441028  0.232899
# 3   0.461113  0.515872  0.972730  0.123212  0.588945  0.301938
# 4   0.556083  0.040340  0.189436  0.560694  0.546085  0.020020
# 5   0.558656  0.401843  0.042836  0.071625  0.050890  0.226957
# 6   0.420180  0.149999  0.849814  0.431108  0.347208  0.371126
# 7   0.245184  0.674401  0.272818  0.964645  0.895334  0.785849
# 8   0.091668  0.403323  0.428573  0.244366  0.961706  0.071670
# 9   0.894229  0.190505  0.612643  0.869586  0.046748  0.759584
# 10  0.163069  0.727378  0.050109  0.698932  0.422243  0.978948

# %%
df1_copy.fillna(1000)
# Out:
#        column_1  column_2  column_3  column_4  column_5  column_6
# 1   1000.000000  0.653859  0.589211  0.746113  0.803063  0.778985
# 2      0.926433  0.422593  0.377389  0.197981  0.441028  0.232899
# 3      0.461113  0.515872  0.972730  0.123212  0.588945  0.301938
# 4      0.556083  0.040340  0.189436  0.560694  0.546085  0.020020
# 5      0.558656  0.401843  0.042836  0.071625  0.050890  0.226957
# 6      0.420180  0.149999  0.849814  0.431108  0.347208  0.371126
# 7      0.245184  0.674401  0.272818  0.964645  0.895334  0.785849
# 8      0.091668  0.403323  0.428573  0.244366  0.961706  0.071670
# 9      0.894229  0.190505  0.612643  0.869586  0.046748  0.759584
# 10     0.163069  0.727378  0.050109  0.698932  0.422243  0.978948

# %%
df1_copy.rename(index={1:'nuovo_index'}, columns={'column_1':'COLONNA_1'})
# Out:
#              COLONNA_1  column_2  column_3  column_4  column_5  column_6
# nuovo_index        NaN  0.653859  0.589211  0.746113  0.803063  0.778985
# 2             0.926433  0.422593  0.377389  0.197981  0.441028  0.232899
# 3             0.461113  0.515872  0.972730  0.123212  0.588945  0.301938
# 4             0.556083  0.040340  0.189436  0.560694  0.546085  0.020020
# 5             0.558656  0.401843  0.042836  0.071625  0.050890  0.226957
# 6             0.420180  0.149999  0.849814  0.431108  0.347208  0.371126
# 7             0.245184  0.674401  0.272818  0.964645  0.895334  0.785849
# 8             0.091668  0.403323  0.428573  0.244366  0.961706  0.071670
# 9             0.894229  0.190505  0.612643  0.869586  0.046748  0.759584
# 10            0.163069  0.727378  0.050109  0.698932  0.422243  0.978948

# %%
df1_copy.reset_index()
# Out:
#    index  column_1  column_2  column_3  column_4  column_5  column_6
# 0      1       NaN  0.653859  0.589211  0.746113  0.803063  0.778985
# 1      2  0.926433  0.422593  0.377389  0.197981  0.441028  0.232899
# 2      3  0.461113  0.515872  0.972730  0.123212  0.588945  0.301938
# 3      4  0.556083  0.040340  0.189436  0.560694  0.546085  0.020020
# 4      5  0.558656  0.401843  0.042836  0.071625  0.050890  0.226957
# 5      6  0.420180  0.149999  0.849814  0.431108  0.347208  0.371126
# 6      7  0.245184  0.674401  0.272818  0.964645  0.895334  0.785849
# 7      8  0.091668  0.403323  0.428573  0.244366  0.961706  0.071670
# 8      9  0.894229  0.190505  0.612643  0.869586  0.046748  0.759584
# 9     10  0.163069  0.727378  0.050109  0.698932  0.422243  0.978948

# %%
df1_copy.sort_values('column_1')
# Out:
#     column_1  column_2  column_3  column_4  column_5  column_6
# 8   0.091668  0.403323  0.428573  0.244366  0.961706  0.071670
# 10  0.163069  0.727378  0.050109  0.698932  0.422243  0.978948
# 7   0.245184  0.674401  0.272818  0.964645  0.895334  0.785849
# 6   0.420180  0.149999  0.849814  0.431108  0.347208  0.371126
# 3   0.461113  0.515872  0.972730  0.123212  0.588945  0.301938
# 4   0.556083  0.040340  0.189436  0.560694  0.546085  0.020020
# 5   0.558656  0.401843  0.042836  0.071625  0.050890  0.226957
# 9   0.894229  0.190505  0.612643  0.869586  0.046748  0.759584
# 2   0.926433  0.422593  0.377389  0.197981  0.441028  0.232899
# 1        NaN  0.653859  0.589211  0.746113  0.803063  0.778985

# %% [markdown]
# (Notare il NaN messo in fondo; per maggiori informazioni, guardare la documentazione ufficiale)

# %% [markdown]
# ### Metodi di Esportazione

# %%
df1.to_csv('df1.csv', columns=['column_1', 'column_5', 'column_2'], index_label='ID')

# %%
df1.to_pickle('df1.pkl')

# %% [markdown]
# ### Metodi di Visualizzazione

# %%
df1_plot = df1.sort_values('column_1')
df1_plot.plot('column_1', ['column_6', 'column_3','column_2'], figsize=(12,8))
# Out:
# <Axes: xlabel='column_1'>

# %%
df1.plot.scatter(x='column_2', y='column_5', c='column_3', colormap='autumn', figsize=(12,8))
# Out:
# <Axes: xlabel='column_2', ylabel='column_5'>

# %%
df1.boxplot(column=['column_3', 'column_2'], figsize=(12,8))
# Out:
# <Axes: >

# %%
df1.loc[:, df1.columns!='column_1'].plot.bar(figsize=(12,8))
# Out:
# <Axes: >

# %%
df1.loc[:, df1.columns!='column_1'].plot.density(figsize=(12,8))
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Caricamento DataFrame

# %%
pd.read_csv('df1.csv')
# Out:
#    ID   column_1  column_5  column_2
# 0   1  10.000000  0.803063  0.653859
# 1   2   0.926433  0.441028  0.422593
# 2   3   0.461113  0.588945  0.515872
# 3   4   0.556083  0.546085  0.040340
# 4   5   0.558656  0.050890  0.401843
# 5   6   0.420180  0.347208  0.149999
# 6   7   0.245184  0.895334  0.674401
# 7   8   0.091668  0.961706  0.403323
# 8   9   0.894229  0.046748  0.190505
# 9  10   0.163069  0.422243  0.727378

# %%
pd.read_csv('df1.csv', usecols=['ID', 'column_1', 'column_2'], index_col='ID')
# Out:
#      column_1  column_2
# ID
# 1   10.000000  0.653859
# 2    0.926433  0.422593
# 3    0.461113  0.515872
# 4    0.556083  0.040340
# 5    0.558656  0.401843
# 6    0.420180  0.149999
# 7    0.245184  0.674401
# 8    0.091668  0.403323
# 9    0.894229  0.190505
# 10   0.163069  0.727378

# %%
pd.read_pickle('df1.pkl')
# Out:
#      column_1  column_2  column_3  column_4  column_5  column_6
# 1   10.000000  0.653859  0.589211  0.746113  0.803063  0.778985
# 2    0.926433  0.422593  0.377389  0.197981  0.441028  0.232899
# 3    0.461113  0.515872  0.972730  0.123212  0.588945  0.301938
# 4    0.556083  0.040340  0.189436  0.560694  0.546085  0.020020
# 5    0.558656  0.401843  0.042836  0.071625  0.050890  0.226957
# 6    0.420180  0.149999  0.849814  0.431108  0.347208  0.371126
# 7    0.245184  0.674401  0.272818  0.964645  0.895334  0.785849
# 8    0.091668  0.403323  0.428573  0.244366  0.961706  0.071670
# 9    0.894229  0.190505  0.612643  0.869586  0.046748  0.759584
# 10   0.163069  0.727378  0.050109  0.698932  0.422243  0.978948

# %% [markdown]
# ## "Affiancamento" di DataFrame

# %%
pd.concat([df1, df1.reset_index()], axis=1)
# Out:
#      column_1  column_2  column_3  column_4  column_5  column_6  index  \
# 1   10.000000  0.653859  0.589211  0.746113  0.803063  0.778985    2.0
# 2    0.926433  0.422593  0.377389  0.197981  0.441028  0.232899    3.0
# 3    0.461113  0.515872  0.972730  0.123212  0.588945  0.301938    4.0
# 4    0.556083  0.040340  0.189436  0.560694  0.546085  0.020020    5.0
# 5    0.558656  0.401843  0.042836  0.071625  0.050890  0.226957    6.0
# 6    0.420180  0.149999  0.849814  0.431108  0.347208  0.371126    7.0
# 7    0.245184  0.674401  0.272818  0.964645  0.895334  0.785849    8.0
# 8    0.091668  0.403323  0.428573  0.244366  0.961706  0.071670    9.0
# 9    0.894229  0.190505  0.612643  0.869586  0.046748  0.759584   10.0
# 10   0.163069  0.727378  0.050109  0.698932  0.422243  0.978948    NaN
# 0         NaN       NaN       NaN       NaN       NaN       NaN    1.0
#
#      column_1  column_2  column_3  column_4  column_5  column_6
# ...
